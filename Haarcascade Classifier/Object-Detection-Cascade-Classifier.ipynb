# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = cv2.imread('images/faces_001.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
image.shape
# Out:
# (2456, 3680, 3)

# %%
plt.imshow(image)

# %%
image = cv2.resize(image, (800,600))

# %%
image.shape
# Out:
# (600, 800, 3)

# %%
plt.imshow(image)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# %%
image_gray.shape
# Out:
# (600, 800)

# %%
#cv2.imshow("Gray",image_gray)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
plt.imshow(image_gray)

# %% [markdown]
# ## Detecting Faces

# %%
face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
detections = face_detector.detectMultiScale(image_gray)

# %%
detections
# Out:
# array([[147, 180,  76,  76],
#        [411, 177,  91,  91],
#        [453, 339,  59,  59],
#        [714, 370,  49,  49],
#        [507,  99,  70,  70],
#        [320, 184, 110, 110],
#        [571,  99,  99,  99],
#        [257, 111,  68,  68],
#        [704, 125,  77,  77],
#        [ 35, 148,  69,  69],
#        [514, 151,  64,  64]], dtype=int32)

# %%
len(detections) # faces detected
# Out:
# 11

# %%
for (x,y,w,h) in detections:
    #print(x,y,w,h)
    cv2.rectangle(image, (x,y), (x+w,y+h), (255,255,0), 2)

plt.imshow(image)
#cv2.imshow('Detected',image)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %% [markdown]
# ## Improve False Postive bounding box with Haarcascade parameters

# %%
image = cv2.imread('images/faces_001.jpg')
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (800,600))
image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
detections = face_detector.detectMultiScale(image_gray, scaleFactor=1.45)  # parameter passed
for (x,y,w,h) in detections:
    cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0), 2)
plt.imshow(image)

cv2.imshow('Detected',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image = cv2.imread('images/faces_002.jpg')
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (800,600))
image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
#detections = face_detector.detectMultiScale(image_gray, scaleFactor=1.45, minNeighbors=6, minSize=(14,14), maxSize=(100,100)) # parameter passed
face_detections = face_detector.detectMultiScale(image_gray, scaleFactor=1.1) # parameter passed
for (x,y,w,h) in face_detections:
    #print(w,h)
    cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0), 2)
plt.imshow(image)

cv2.imshow('Detected',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Eye Detection

# %%
image = cv2.imread('images/faces_001.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (800,600))
image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_detector = cv2.CascadeClassifier('haarcascade_eye.xml')
#detections = face_detector.detectMultiScale(image_gray, scaleFactor=1.45, minNeighbors=6, minSize=(14,14), maxSize=(100,100)) # parameter passed
face_detections = face_detector.detectMultiScale(image_gray, scaleFactor=1.2) # parameter passed
for (x,y,w,h) in face_detections:
    cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0), 2)

eye_detections = eye_detector.detectMultiScale(image_gray, scaleFactor=1.12, maxSize=(35,35))
for (x,y,w,h) in eye_detections:
    #print(w,h)
    cv2.rectangle(image, (x,y), (x+w, y+h), (0,0,255), 2)

plt.imshow(image)

cv2.imshow('Detected',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Full body Detections

# %%
image = cv2.imread('images/full_body_001.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (800,600))
image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
fullbody_detector = cv2.CascadeClassifier('haarcascade_fullbody.xml')
fullbody_detections = fullbody_detector.detectMultiScale(image_gray, scaleFactor=1.04, minNeighbors=5, minSize=(50,50)) # parameter passed
for (x,y,w,h) in fullbody_detections:
    #print(w,h)
    cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0), 2)
plt.imshow(image)

cv2.imshow('Detected',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Wallclock Detections

# %%
image = cv2.imread('images/wallclock_001.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (800,600))
image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
clock_detector = cv2.CascadeClassifier('haarcascade_wallclock.xml')
clock_detections = clock_detector.detectMultiScale(image_gray, scaleFactor=1.09, minNeighbors=1) # parameter passed
for (x,y,w,h) in clock_detections:
    #print(w,h)
    cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0), 2)
plt.imshow(image)

cv2.imshow('Detected',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Car Detection

# %%
image = cv2.imread('images/cars_001.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (800,600))
image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
car_detector = cv2.CascadeClassifier('haarcascade_car.xml')
car_detections = car_detector.detectMultiScale(image_gray, scaleFactor=1.06) # parameter passed
for (x,y,w,h) in car_detections:
    #print(w,h)
    cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0), 2)
plt.imshow(image)

cv2.imshow('Detected',image)
cv2.waitKey(0)
cv2.destroyAllWindows()
